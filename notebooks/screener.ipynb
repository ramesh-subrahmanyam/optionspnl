# %%
#!pip install finnhub-python

# %%
import time
import pandas as pd
from datetime import datetime, timedelta
import io
from contextlib import redirect_stdout
import logging
import yfinance as yf
import finnhub 
import numpy as np

logging.getLogger('yfinance').setLevel(logging.CRITICAL)

# %% [markdown]
# ### Code to populate the earning dates database

# %%
# Earnings database management functions have been moved to manage_earnings_database.py
# Use: python manage_earnings_database.py --update
# Or import functions: from manage_earnings_database import setup, store_symbols

# %%
# To initialize or update the earnings database, use the command-line tool:
# python manage_earnings_database.py --update   # Update for next 6 months
# python manage_earnings_database.py --reset    # Wipe and rebuild
# python manage_earnings_database.py --add TSLA # Add a new symbol

# %% [markdown]
# ### Code to screen out stocks within a specified window today to date X

# %%
# Screening functions have been moved to screener.py
from screener import get_stocks_within_days, get_stocks_outside_days, get_stocks_outside_date

# %%
# StockData class has been moved to screener.py
from screener import StockData

# %% [markdown]
# ### Print stocks with earnings outside a specified window and their returns over various timeframes

# %%
end_date_str = "2025-12-15" # no earings between now and this date
earnings_df=get_stocks_outside_date(end_date_str)

stock_data = StockData(list(earnings_df.symbol))
stock_data.fetch_price_data("2024-12-01", "2026-07-23")
stock_data.add_returns(5)
stock_data.add_returns(22)
stock_data.add_returns(66)
stock_data.attach_earnings_dates(earnings_df)
print(stock_data.df)
# Out:
# File earnings_dates/M1.csv not found
# File earnings_dates/M2.csv not found
# File earnings_dates/M3.csv not found
# File earnings_dates/M4.csv not found
# File earnings_dates/M5.csv not found
# File earnings_dates/M6.csv not found
# File earnings_dates/M7.csv not found
# File earnings_dates/M8.csv not found
# File earnings_dates/M9.csv not found
# File earnings_dates/M10.csv not found
# File earnings_dates/M11.csv not found
# File earnings_dates/M12.csv not found
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 5
#       2 earnings_df=get_stocks_outside_date(end_date_str)
#       4 stock_data = StockData(list(earnings_df.symbol))
# ----> 5 stock_data.fetch_price_data("2024-12-01", "2026-07-23")
#       6 stock_data.add_returns(5)
#       7 stock_data.add_returns(22)
#
# Cell In[23], line 22, in StockData.fetch_price_data(self, start_date, end_date)
#      19     stock_data.reset_index(inplace=True)
#      20     data.append(stock_data[['symbol', 'Date', 'Close']])
# ---> 22 combined_data = pd.concat(data)
#      23 combined_data.columns = ['symbol', 'date', 'price']
#      24 return combined_data
#
# File /opt/anaconda3/envs/position_analysis/lib/python3.9/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File /opt/anaconda3/envs/position_analysis/lib/python3.9/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File /opt/anaconda3/envs/position_analysis/lib/python3.9/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
symbols=['A',  'AAPL', 'ABBV', 'ABC', 'ABNB', 'ABT', 'ACN', 'ADI', 'ADSK', 'AFL', 'AFRM', 
         'AGM', 'AJG', 'ALB', 'ALNY', 'AMAT', 'AMD', 'AMG', 'AMZN', 'ANSS', 'APD', 'APH', 
         'ARE', 'ARKK', 'AVAV', 'AVGO', 'AWK', 'AXON', 'BA', 'BABA', 'BBY', 'BIDU', 'BR',
           'BX', 'CARR', 'CAT', 'CB', 'CBRL', 'CE', 'CHTR', 'CLDX', 'CME', 'CMI', 'CMPR',
             'COIN', 'CRM', 'CRWD', 'DASH', 'DELL', 'DG', 'DHR', 'DIA', 'DLTR', 'DOCU', 
             'DRI', 'DXJ', 'EL', 'ENPH', 'ETN', 'ETSY', 'EWW', 'EWY', 'FBT', 'FCX', 'FDX',
               'FERG', 'FI', 'FIVE', 'FSLR', 'FXI', 'GDX', 'GE', 'GGG', 'GLD', 'GM', 'GOOGL', 
               'GS', 'HD', 'HEI', 'HLT', 'HON', 'HSY', 'HUM', 'IBB', 'IBM', 'ICE', 'IEX', 'IGIB', 
               'IJR', 'IJS', 'ILMN', 'INTC', 'ISRG', 'ITA', 'ITB', 'ITW', 'IWM', 'IYR', 'JACK', 'JPM', 
               'KKR', 'KOLD', 'KWR', 'LEN', 'LHX', 'LNN', 'LOW', 'LULU', 'MCHP', 'MDB', 'META', 'MIDD', 
               'MLR', 'MRNA', 'MS', 'MSFT', 'MU', 'NKE', 'NTES', 'NVDA', 'NVDL', 'NVMI', 'OKTA', 'ON', 'OTIS', 
               'PANW', 'PAYX', 'PDD', 'PGR', 'PHM', 'PII', 'PYPL', 'QUAL', 'RH', 'ROK', 'ROKU', 'SAIC', 
               'SCHW', 'SCL', 'SHW', 'SLGN', 'SMCI', 'SMH', 'SMIN', 'SPXL', 'SPY', 'STZ', 'SYK', 'SYY', 
               'TAN', 'TGT', 'THO', 'TLT', 'TMF', 'TMUS', 'TREX', 'TSLA', 'TSM', 'TTD', 'UAL', 'UBER', 
               'UGA', 'UNH', 'UNP', 'UPS', 'USO', 'VBR', 'VCLT', 'VGK', 'VNQ', 'VO', 'VRT', 'VTI', 
               'VTV', 'VUG', 'W', 'WDAY', 'WMT', 'WSM', 'WYNN', 'XBI', 'XHB', 'XLC', 
         'XLE', 'XLI', 'XLK', 'XLP', 'XLV', 'XLY', 'XME', 'XOM', 'XOP', 'XPO', 'XRT', 'ZBRA']

# %% [markdown]
# ### Complete Screening Workflow

# %%
# Import the main screening function
from screener import main

# Run the screening workflow
# Parameters:
#   days_forward: Number of days to check for earnings (default: 30)
#   update_earnings: Whether to update earnings database first (default: True)
#   output_file: Where to save results (default: 'data/screener_output.csv')
#   use_cache: Use historical price cache (default: True)
#   staleness_days: Cache expiration in days (default: 1)

results = main(
    days_forward=30,
    update_earnings=True,
    output_file='data/screener_output.csv',
    use_cache=True,
    staleness_days=1
)
